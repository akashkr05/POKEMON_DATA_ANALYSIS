# %% [markdown]
# # POKEMON DATA ANALYSIS

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\kumar\\Downloads\\pokemon.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.isnull().count()
sns.heatmap(df.isnull())
df.notnull().count()
sns.heatmap(df.notnull())
df.corr()  # correlation
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097614  0.102298  0.094786  0.088759  0.085817
# HP          0.097614  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102298  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094786  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.088759  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085817  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.010733  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.982516  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.153396  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.010733    0.982516   0.153396
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.head(40)
# Out:
#      #                       Name    Type 1  Type 2  HP  Attack  Defense  \
# 0    1                  Bulbasaur     Grass  Poison  45      49       49
# 1    2                    Ivysaur     Grass  Poison  60      62       63
# 2    3                   Venusaur     Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur     Grass  Poison  80     100      123
# 4    4                 Charmander      Fire     NaN  39      52       43
# 5    5                 Charmeleon      Fire     NaN  58      64       58
# 6    6                  Charizard      Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X      Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y      Fire  Flying  78     104       78
# 9    7                   Squirtle     Water     NaN  44      48       65
# 10   8                  Wartortle     Water     NaN  59      63       80
# 11   9                  Blastoise     Water     NaN  79      83      100
# ...

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
# fetch particular column
#print(df['Sp. Atk'])  
#print(df['Defense'])
df.isnull().count()
df.notnull().count()
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
print(df['Name'][4:15]) # column name, row numbers ( last row excluded )
# Out:
# 4                    Charmander
# 5                    Charmeleon
# 6                     Charizard
# 7     CharizardMega Charizard X
# 8     CharizardMega Charizard Y
# 9                      Squirtle
# 10                    Wartortle
# 11                    Blastoise
# 12      BlastoiseMega Blastoise
# 13                     Caterpie
# 14                      Metapod
# Name: Name, dtype: object

# %%
# iloc for specific location means fetch sigle row
print(df.iloc[0])
print()
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
print(df.iloc[1:6])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %%
print(df.iloc[5])
# Out:
# #                      5
# Name          Charmeleon
# Type 1              Fire
# Type 2               NaN
# HP                    58
# Attack                64
# Defense               58
# Sp. Atk               80
# Sp. Def               65
# Speed                 80
# Generation             1
# Legendary          False
# Name: 5, dtype: object

# %%
print(df.iloc[1:3])
# Out:
#    #      Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2   Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3  Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 1           1      False
# 2           1      False

# %%
 # fetch krega data agar column me grass jha jha par hai sabki row aa jayegi

# %%
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')] # 2 column ke same data lena hai
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df.describe() # it tells the count, mean, std, min,mode
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('#',ascending=False)
df
df.sort_values('HP',ascending=False).head(5)  # desceding order
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
#
#      Speed  Generation  Legendary
# 261     55           2      False
# 121     50           1      False
# 217     33           2      False
# 351     60           3      False
# 655     65           5      False

# %%
# two column sort
df2 = df.sort_values(['Type 1','HP'],ascending=False)
print(df2)
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 351  321    Wailord  Water     NaN  170      90       45       90       45
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %%
df3 = df.sort_values(['Attack','Defense','Sp. Atk'],ascending=True)
print(df3)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 488  440                  Happiny   Normal       NaN  100       5        5
# 121  113                  Chansey   Normal       NaN  250       5        5
# 261  242                  Blissey   Normal       NaN  255      10       10
# 139  129                 Magikarp    Water       NaN   20      10       55
# 230  213                  Shuckle      Bug      Rock   20      10      230
# ..   ...                      ...      ...       ...  ...     ...      ...
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Generation']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    274
# 1       80     60           1      False    346
# 2      100     80           1      False    446
# 3      120     80           1      False    546
# 4       50     65           1      False    245

# %%
#df.drop(columns=['Total'])
#df
#del df['Total'] # delete column
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    274
# 1       80     60           1      False    346
# 2      100     80           1      False    446
# 3      120     80           1      False    546
# 4       50     65           1      False    245

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    274
# 1       80     60           1      False    346
# 2      100     80           1      False    446
# 3      120     80           1      False    546
# 4       50     65           1      False    245

# %%
df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df['HP']>60)]
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    274
# ...

# %%
df1 = df.loc[(df['Name']=='VenusaurMega Venusaur') & (df['Type 2']=='Poison')]
print(df1)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 3      120     80           1      False    546

# %%
df.loc()
# Out:
#     #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0   1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1   2                    Ivysaur  Grass  Poison  60      62       63       80
# 2   3                   Venusaur  Grass  Poison  80      82       83      100
# 3   3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4   4                 Charmander   Fire     NaN  39      52       43       60
# 5   5                 Charmeleon   Fire     NaN  58      64       58       80
# 6   6                  Charizard   Fire  Flying  78      84       78      109
# 7   6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8   6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9   7                   Squirtle  Water     NaN  44      48       65       50
# 10  8                  Wartortle  Water     NaN  59      63       80       65
# ...
